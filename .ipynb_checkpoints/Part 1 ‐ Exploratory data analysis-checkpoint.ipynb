# %%
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt

# %%
file = 'logins.json'
logins = pd.read_json(file)
logins.head()
# Out:
#            login_time
# 0 1970-01-01 20:13:18
# 1 1970-01-01 20:16:10
# 2 1970-01-01 20:16:37
# 3 1970-01-01 20:16:36
# 4 1970-01-01 20:26:21

# %%
logins['15_minute_intervals'] = [i*15 for i in range(logins.size)]
logins.head()
# Out:
#            login_time  15_minute_intervals
# 0 1970-01-01 20:13:18                    0
# 1 1970-01-01 20:16:10                   15
# 2 1970-01-01 20:16:37                   30
# 3 1970-01-01 20:16:36                   45
# 4 1970-01-01 20:26:21                   60

# %%
logins['base_time'] = dt.datetime(logins['login_time'].dt.year[0],
                                  logins['login_time'].dt.month[0],
                                  logins['login_time'].dt.day[0],
                                  logins['login_time'].dt.hour[0],
                                  minute=0)
logins.head()
# Out:
#            login_time  15_minute_intervals           base_time
# 0 1970-01-01 20:13:18                    0 1970-01-01 20:00:00
# 1 1970-01-01 20:16:10                   15 1970-01-01 20:00:00
# 2 1970-01-01 20:16:37                   30 1970-01-01 20:00:00
# 3 1970-01-01 20:16:36                   45 1970-01-01 20:00:00
# 4 1970-01-01 20:26:21                   60 1970-01-01 20:00:00

# %%
logins['interval_start'] = logins['base_time'] + pd.TimedeltaIndex(logins['15_minute_intervals'], unit='m')
logins.head()
# Out:
#            login_time  15_minute_intervals           base_time  \
# 0 1970-01-01 20:13:18                    0 1970-01-01 20:00:00
# 1 1970-01-01 20:16:10                   15 1970-01-01 20:00:00
# 2 1970-01-01 20:16:37                   30 1970-01-01 20:00:00
# 3 1970-01-01 20:16:36                   45 1970-01-01 20:00:00
# 4 1970-01-01 20:26:21                   60 1970-01-01 20:00:00
#
#        interval_start
# 0 1970-01-01 20:00:00
# 1 1970-01-01 20:15:00
# 2 1970-01-01 20:30:00
# 3 1970-01-01 20:45:00
# 4 1970-01-01 21:00:00

# %%
logins['interval_end'] = logins['interval_start'] + pd.Timedelta(15, unit='m')
logins.head()
# Out:
#            login_time  15_minute_intervals           base_time  \
# 0 1970-01-01 20:13:18                    0 1970-01-01 20:00:00
# 1 1970-01-01 20:16:10                   15 1970-01-01 20:00:00
# 2 1970-01-01 20:16:37                   30 1970-01-01 20:00:00
# 3 1970-01-01 20:16:36                   45 1970-01-01 20:00:00
# 4 1970-01-01 20:26:21                   60 1970-01-01 20:00:00
#
#        interval_start        interval_end
# 0 1970-01-01 20:00:00 1970-01-01 20:15:00
# 1 1970-01-01 20:15:00 1970-01-01 20:30:00
# 2 1970-01-01 20:30:00 1970-01-01 20:45:00
# 3 1970-01-01 20:45:00 1970-01-01 21:00:00
# 4 1970-01-01 21:00:00 1970-01-01 21:15:00

# %%
bins = pd.IntervalIndex.from_tuples(
    [
        (logins.iloc[i]['interval_start'], logins.iloc[i]['interval_end'])
        for i in range(logins.shape[0])
    ]
)
logins['binning'] = pd.cut(logins['login_time'], bins=bins)
logins.head()
# Out:
#            login_time  15_minute_intervals           base_time  \
# 0 1970-01-01 20:13:18                    0 1970-01-01 20:00:00
# 1 1970-01-01 20:16:10                   15 1970-01-01 20:00:00
# 2 1970-01-01 20:16:37                   30 1970-01-01 20:00:00
# 3 1970-01-01 20:16:36                   45 1970-01-01 20:00:00
# 4 1970-01-01 20:26:21                   60 1970-01-01 20:00:00
#
#        interval_start        interval_end  \
# 0 1970-01-01 20:00:00 1970-01-01 20:15:00
# 1 1970-01-01 20:15:00 1970-01-01 20:30:00
# 2 1970-01-01 20:30:00 1970-01-01 20:45:00
# 3 1970-01-01 20:45:00 1970-01-01 21:00:00
# 4 1970-01-01 21:00:00 1970-01-01 21:15:00
#
#                                       binning
# 0  (1970-01-01 20:00:00, 1970-01-01 20:15:00]
# 1  (1970-01-01 20:15:00, 1970-01-01 20:30:00]
# 2  (1970-01-01 20:15:00, 1970-01-01 20:30:00]
# 3  (1970-01-01 20:15:00, 1970-01-01 20:30:00]
# 4  (1970-01-01 20:15:00, 1970-01-01 20:30:00]

# %%
binned_logins = logins[['login_time', 'binning']].groupby('binning').agg('count')
binned_logins.head()
# Out:
#                                             login_time
# binning
# (1970-01-01 20:00:00, 1970-01-01 20:15:00]           2
# (1970-01-01 20:15:00, 1970-01-01 20:30:00]           6
# (1970-01-01 20:30:00, 1970-01-01 20:45:00]           9
# (1970-01-01 20:45:00, 1970-01-01 21:00:00]           7
# (1970-01-01 21:00:00, 1970-01-01 21:15:00]           1

# %%
binned_logins.rename({'login_time':'count'}, axis=1, inplace=True)
binned_logins.head()
# Out:
#                                             count
# binning
# (1970-01-01 20:00:00, 1970-01-01 20:15:00]      2
# (1970-01-01 20:15:00, 1970-01-01 20:30:00]      6
# (1970-01-01 20:30:00, 1970-01-01 20:45:00]      9
# (1970-01-01 20:45:00, 1970-01-01 21:00:00]      7
# (1970-01-01 21:00:00, 1970-01-01 21:15:00]      1

# %%
binned_logins.reset_index(inplace=True)
binned_logins.head()
# Out:
#                                       binning  count
# 0  (1970-01-01 20:00:00, 1970-01-01 20:15:00]      2
# 1  (1970-01-01 20:15:00, 1970-01-01 20:30:00]      6
# 2  (1970-01-01 20:30:00, 1970-01-01 20:45:00]      9
# 3  (1970-01-01 20:45:00, 1970-01-01 21:00:00]      7
# 4  (1970-01-01 21:00:00, 1970-01-01 21:15:00]      1

# %%
count_vs_interval = pd.concat([binned_logins, logins[['login_time', 'interval_start']]], axis=1)
count_vs_interval.head()
# Out:
#                                       binning  count          login_time  \
# 0  (1970-01-01 20:00:00, 1970-01-01 20:15:00]      2 1970-01-01 20:13:18
# 1  (1970-01-01 20:15:00, 1970-01-01 20:30:00]      6 1970-01-01 20:16:10
# 2  (1970-01-01 20:30:00, 1970-01-01 20:45:00]      9 1970-01-01 20:16:37
# 3  (1970-01-01 20:45:00, 1970-01-01 21:00:00]      7 1970-01-01 20:16:36
# 4  (1970-01-01 21:00:00, 1970-01-01 21:15:00]      1 1970-01-01 20:26:21
#
#        interval_start
# 0 1970-01-01 20:00:00
# 1 1970-01-01 20:15:00
# 2 1970-01-01 20:30:00
# 3 1970-01-01 20:45:00
# 4 1970-01-01 21:00:00

# %%
# trim bins with intervals greater than last login_time (since they will never be used)
last_login_time = count_vs_interval['login_time'].sort_values(ascending=True).iloc[-1]
count_vs_interval = count_vs_interval[count_vs_interval['interval_start'] < last_login_time]

# %%
plt.plot(count_vs_interval['interval_start'], count_vs_interval['count'])
plt.xticks(rotation=60)
plt.show()

# %%
hist_data = count_vs_interval[['count', 'interval_start']].set_index('interval_start')
hist_data.head()
# Out:
#                      count
# interval_start
# 1970-01-01 20:00:00      2
# 1970-01-01 20:15:00      6
# 1970-01-01 20:30:00      9
# 1970-01-01 20:45:00      7
# 1970-01-01 21:00:00      1

# %%
values = count_vs_interval['count']
edges = count_vs_interval['interval_start']
edges = pd.concat([edges, edges.iloc[-1] + pd.Series(pd.Timedelta(15, unit='m'))], axis=0, ignore_index=True)

# %%
fig, ax = plt.subplots(figsize=(10,5))
plt.stairs(values, edges)
plt.xticks(rotation=60)
plt.grid(True)
plt.show()
